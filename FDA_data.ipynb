# %%
# adding dependencies and modules. 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
import json
import seaborn as sns
import statistics
import math
from scipy import stats

# importing API key from the FDA 
from api_keys import api_key

# %%
base_url = "https://api.fda.gov/drug/event.json?search=patient.reaction.reactionmeddrapt:='DRUG+ADMINISTRATION+ERROR'=+AND+receivedate:[20100101+TO+20211108]+AND+patient.reaction.reactionoutcome:5"

req = requests.get(base_url)
json_data = req.json()
print(json_data)
# Out:
# {'meta': {'disclaimer': 'Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.', 'terms': 'https://open.fda.gov/terms/', 'license': 'https://open.fda.gov/license/', 'last_updated': '2021-11-04', 'results': {'skip': 0, 'limit': 1, 'total': 4823}}, 'results': [{'safetyreportversion': '4', 'safetyreportid': '10004186', 'primarysourcecountry': 'US', 'occurcountry': 'US', 'transmissiondateformat': '102', 'transmissiondate': '20141212', 'reporttype': '1', 'serious': '1', 'seriousnessdeath': '1', 'receivedateformat': '102', 'receivedate': '20140312', 'receiptdateformat': '102', 'receiptdate': '20140502', 'fulfillexpeditecriteria': '1', 'companynumb': 'US-INCYTE CORPORATION-2013IN003064', 'duplicate': '1', 'reportduplicate': {'duplicatesource': 'INCYTE', 'duplicatenumb': 'US-INCYTE CO
# ...

# %%
base_url = "https://api.fda.gov/drug/event.json?search=patient.reaction.reactionmeddrapt:='DRUG+ADMINISTRATION+ERROR'=+AND+receivedate:[20100101+TO+20211108]+AND+patient.reaction.reactionoutcome:5"
print(base_url)
# Out:
# https://api.fda.gov/drug/event.json?search=patient.reaction.reactionmeddrapt:='DRUG+ADMINISTRATION+ERROR'=+AND+receivedate:[20100101+TO+20211108]+AND+patient.reaction.reactionoutcome:5

# %%
req = requests.get(base_url)
        
json_data = req.json()

# %%
json_data['results'][0]['occurcountry']
# Out:
# 'US'

# %%
"https://api.fda.gov/drug/event.json?search=patient.reaction.reactionmeddrapt:='DRUG+ADMINISTRATION+ERROR'=+AND+receivedate:[20100101+TO+20211108]+AND+patient.reaction.reactionoutcome:5"

# %%
for item in json_data['results']:
    print(item)
# Out:
# {'safetyreportversion': '4', 'safetyreportid': '10004186', 'primarysourcecountry': 'US', 'occurcountry': 'US', 'transmissiondateformat': '102', 'transmissiondate': '20141212', 'reporttype': '1', 'serious': '1', 'seriousnessdeath': '1', 'receivedateformat': '102', 'receivedate': '20140312', 'receiptdateformat': '102', 'receiptdate': '20140502', 'fulfillexpeditecriteria': '1', 'companynumb': 'US-INCYTE CORPORATION-2013IN003064', 'duplicate': '1', 'reportduplicate': {'duplicatesource': 'INCYTE', 'duplicatenumb': 'US-INCYTE CORPORATION-2013IN003064'}, 'primarysource': {'reportercountry': 'US', 'qualification': '5'}, 'sender': {'sendertype': '2', 'senderorganization': 'FDA-Public Use'}, 'receiver': {'receivertype': '6', 'receiverorganization': 'FDA'}, 'patient': {'patientonsetage': '67', 'patientonsetageunit': '801', 'patientsex': '1', 'reaction': [{'reactionmeddraversionpt': '17.0', 'reactionmeddrapt': 'Thrombotic microangiopathy', 'reactionoutcome': '5'}, {'reactionmeddraversionpt': '17
# ...

# %% [markdown]
# DMEPA defines a medication error as any preventable event that may cause or lead to inappropriate medication use or patient harm while the medication is in the control of the health care professional, patient, or consumer.

# %%
medical_error = {'generic drug name':[],
                'reaction report':[],
                'reaction outcome':[],
                'drug start date':[],
                'occur country':[],
                'patient sex':[],
                'patient age':[],}


base_url = "https://api.fda.gov/drug/event.json?search=patient.reaction.reactionmeddrapt:='DRUG+ADMINISTRATION+ERROR'=+AND+receivedate:[20100101+TO+20211108]+AND+patient.reaction.reactionoutcome:5"

req = requests.get(base_url)
        
json_data = req.json()
        


for i in range(len(json_data)):
        
    #medical_error['generic drug name'].append(error_datalist[0]['drug']['openfda']['generic_name'])
    #medical_error['reaction report'].append(error_datalist[0]['patient']['reaction']['reactionmeddrapt'])
    #medical_error['reaction outcome'].append(error_datalist[0]['patient']['reaction']['reactionoutcome'])
    #medical_error['drug start date'].append(error_datalist[0]['drug']['drugstartdate'])
    #medical_error['occur country'].append(error_datalist[0]['occurcountry'])
    #medical_error['patient sex'].append(error_datalist[0]['patient']['patientsex'])
    medical_error['patient age'].append(json_data['results']['patient']['patientonsetage'])

print(medical_error)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/zx/rtlkvk155rx_pz72fst65zhh0000gn/T/ipykernel_69128/145417858.py in <module>
#      24     #medical_error['occur country'].append(error_datalist[0]['occurcountry'])
#      25     #medical_error['patient sex'].append(error_datalist[0]['patient']['patientsex'])
# ---> 26     medical_error['patient age'].append(json_data['results']['patient']['patientonsetage'])
#      27
#      28 print(medical_error)
#
# TypeError: list indices must be integers or slices, not str

# %%
url='https://api.fda.gov/drug/event.json?search=patient.drug.openfda.pharm_class_epc.exact:"Benzodiazepine+[EPC]"+AND+patient.patientsex:"2"+AND+patient.patientonsetage:' + '"' + str(age) + '"'+'+AND+receivedate:[20150101+TO+20211001]&count=receivedate'
print(url)
# Out:
# https://api.fda.gov/drug/event.json?search=patient.drug.openfda.pharm_class_epc.exact:"Benzodiazepine+[EPC]"+AND+patient.patientsex:"2"+AND+patient.patientonsetage:"100"+AND+receivedate:[20150101+TO+20211001]&count=receivedate

# %%
base_url = "https://api.fda.gov/drug/event.json?search=patient.reaction.reactionmeddrapt:='DRUG+ADMINISTRATION+ERROR'=+AND+receivedate:[20100101+TO+20211108]+AND+patient.reaction.reactionoutcome:5"
        
req = requests.get(base_url)
        
json_data = req.json()
        
error_datalist = json_data['results']
        
print(error_datalist)
# Out:
# [{'safetyreportversion': '4', 'safetyreportid': '10004186', 'primarysourcecountry': 'US', 'occurcountry': 'US', 'transmissiondateformat': '102', 'transmissiondate': '20141212', 'reporttype': '1', 'serious': '1', 'seriousnessdeath': '1', 'receivedateformat': '102', 'receivedate': '20140312', 'receiptdateformat': '102', 'receiptdate': '20140502', 'fulfillexpeditecriteria': '1', 'companynumb': 'US-INCYTE CORPORATION-2013IN003064', 'duplicate': '1', 'reportduplicate': {'duplicatesource': 'INCYTE', 'duplicatenumb': 'US-INCYTE CORPORATION-2013IN003064'}, 'primarysource': {'reportercountry': 'US', 'qualification': '5'}, 'sender': {'sendertype': '2', 'senderorganization': 'FDA-Public Use'}, 'receiver': {'receivertype': '6', 'receiverorganization': 'FDA'}, 'patient': {'patientonsetage': '67', 'patientonsetageunit': '801', 'patientsex': '1', 'reaction': [{'reactionmeddraversionpt': '17.0', 'reactionmeddrapt': 'Thrombotic microangiopathy', 'reactionoutcome': '5'}, {'reactionmeddraversionpt': '1
# ...

# %%
base_url = "https://api.fda.gov/drug/event.json?search=patient.reaction.reactionmeddrapt:='DRUG+ADMINISTRATION+ERROR'=+AND+receivedate:[20100101+TO+20211108]+AND+patient.reaction.reactionoutcome:5"

req = requests.get(base_url)
        
json_data = req.json()
        
error_datalist = json_data['results']

print(error_datalist)
# Out:
# [{'safetyreportversion': '4', 'safetyreportid': '10004186', 'primarysourcecountry': 'US', 'occurcountry': 'US', 'transmissiondateformat': '102', 'transmissiondate': '20141212', 'reporttype': '1', 'serious': '1', 'seriousnessdeath': '1', 'receivedateformat': '102', 'receivedate': '20140312', 'receiptdateformat': '102', 'receiptdate': '20140502', 'fulfillexpeditecriteria': '1', 'companynumb': 'US-INCYTE CORPORATION-2013IN003064', 'duplicate': '1', 'reportduplicate': {'duplicatesource': 'INCYTE', 'duplicatenumb': 'US-INCYTE CORPORATION-2013IN003064'}, 'primarysource': {'reportercountry': 'US', 'qualification': '5'}, 'sender': {'sendertype': '2', 'senderorganization': 'FDA-Public Use'}, 'receiver': {'receivertype': '6', 'receiverorganization': 'FDA'}, 'patient': {'patientonsetage': '67', 'patientonsetageunit': '801', 'patientsex': '1', 'reaction': [{'reactionmeddraversionpt': '17.0', 'reactionmeddrapt': 'Thrombotic microangiopathy', 'reactionoutcome': '5'}, {'reactionmeddraversionpt': '1
# ...
